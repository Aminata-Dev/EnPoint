# %%
# %load_ext autoreload
# %autoreload 2

# %%
from get_word_infos import WordInfoFetcher

word = "marquee"

fetcher = WordInfoFetcher(word)

fetcher.save_word_info_to_csv(
    # source = "",
    # example = """
#         """
    )

fetcher.show_word_infos()
# Out:
# ✅ 'marquee' added to vocabulary_history.csv
#
# Word or phrasal verb: marquee
# Cambridge Dictionary URL: https://dictionary.cambridge.org/dictionary/english/marquee
#
# ------------------------------
#
# BRITISH ENGLISH PRONUNCIATION PART:
#  > Phonetic Transcription: /mɑːˈkiː/
#  > Pronunciation Youtube videos (Youglish): https://youglish.com/pronounce/marquee/english/uk/
# ------------------------------
# DEFINITIONS:
#   1. a covered entrance to a theater with a sign that shows the names of the movies or play that you can see
#   2. a roof-like structure that sticks out over the entrance to a public building, especially a theatre, and on which there is usually a sign
#   3. a large tent used for eating and drinking in at events held mainly outside that involve a lot of people
#   4. being the main performer or sports person in a show, film, sports event, etc. or being the performer, etc. whose name will attract most people to the show, film, etc.
# ------------------------------
# EXAMPLES:
#   1. We're planning to hold the wedding reception in a marquee in the garden.
#   2. The studio chiefs wanted a marquee name in the lead role, not some unknown.

# %%
# %%capture
# !python3 -m pip install google-genai

# %%
# !python3 utils/call_llm_gemini.py -up "'murky' vs. 'marquee' pronunciation difference ?"
# Out:
# --- PUPIL QUESTION ---
# 'murky' vs. 'marquee' pronunciation difference ?
# --- COACH PRONUNCIATION ANSWER ---
# Hello! I would be delighted to help you with these two words. They are a fantastic example of how vowel quality and word stress can completely change the meaning in British English.
#
# For a French speaker, the main challenges here are the **vowel sounds** and the **word stress**.
#
# Here is the breakdown:
#
# ---
#
# ### 1. Murky
# *   **Phonetic Transcription:** /ˈmɜːki/
# *   **Stress:** The stress is on the **first** syllable (**MUR**-ky).
#
# **Advice for French speakers:**
# *   **The /ɜː/ sound:** This is the "nurse" vowel. It doesn't exist in French. French speakers often try to pronounce it like the "eu" in *fleur* or *peur*, but the English /ɜː/ is more neutral. Keep your lips relaxed (not rounded) and your tongue in the middle of your mouth.
# *   **The 'r':** In British English (Received Pronunciation), the 'r' is silent. It simply serves to make the vowel longer. Do not use the French /ʁ/ sound!
# *   **The final /i/:** This is short and crisp.
#
# **Similar words:** *Bird* /bɜːd/, *Word* /wɜːd/, *First* /fɜːst/.
#
# ---
#
# ### 2. Marquee
# *   **Phonetic Transcription:** /mɑːˈkiː/
# *   **Stress:** The stress is on the **second** syllable (mar-**QUEE**).
#
# **Advice for French speakers:**
# *   **The /ɑː/ sound:** This is a long "ah" sound, like when you open your mouth for a doctor. It is similar to the 'a' in the French word *bas*, but held longer. Again, the 'r' is silent.
# *   **The /iː/ sound:** This is a long "ee" sound. Because the stress is on this syllable, you must stretch the sound out: /mɑːˈkiː/.
# *   **Word Stress:** This is the biggest difference. In "marquee," the first syllable is very short and weak, while the second is loud and long.
#
# **Similar words:** *Car* /kɑː/, *Star* /stɑː/, *Tree* /triː/.
#
# ---
#
# ### The Key Differences Summary
#
# | Feature | **Murky** | **Marquee** |
# | :--- | :--- | :--- |
# | **Stress** | **First** syllable (MUR-ky) | **Second** syllable (mar-QUEE) |
# | **First Vowel** | /ɜː/ (like "her") | /ɑː/ (like "car") |
# | **Second Vowel** | /i/ (short) | /iː/ (long) |
#
# ### A Tip for You:
# To practice the difference, try saying this sentence:
# > "The **mar**quee looked **mur**ky in the rain."
#
# Focus on shifting the "weight" of the word. In **Murky**, the weight is at the start. In **Marquee**, the weight is at the end.
#
# Does that help clarify the difference for you? Would you like to try another pair?

# %% [markdown]
# # Evaluation

# %%
# %run live_speech_to_text.py
# Out:
# Live Speech-to-Text started. Speak into the microphone...
# The script will auto-transcribe when it detects XX second of silence.
# Press Ctrl+C to stop.
#
#
#
# Bar key
#
# Marky.
# Marky
#
#
# Markey
#
# Marquis.
#
# Mark it
#
# Markey.
#
# Markey
#
# Stopping...
