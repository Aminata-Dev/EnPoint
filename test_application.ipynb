# %%
from get_word_infos import WordInfoFetcher

word = "fan out"
fetcher_audio = WordInfoFetcher(word)

fetcher_audio.show_word_infos()
# Out:
# Word or phrasal verb: fan out
# Cambridge Dictionary URL: https://dictionary.cambridge.org/dictionary/english/fan-out
#
# ------------------------------
#
# PRONUNCIATION PART:
#  > English Transcription: /fæn/
#  > Youglish UK Pronunciation Youtube videos: https://youglish.com/pronounce/fan-out/english/uk/
# ------------------------------
# DEFINITIONS:
#   1. If a group of people fan out, they move in different directions from a single point.
#   2. to spread out over a wide area:
# ------------------------------
# EXAMPLES:
#   1. The police fanned out over the west side of the park.

# %%
# %run live_speech_to_text.py
# Out:
# Live Speech-to-Text started. Speak into the microphone...
# The script will auto-transcribe when it detects XX second of silence.
# Press Ctrl+C to stop.
#
#
# This is a test.
#
# Stopping...
