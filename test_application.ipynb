# %%
# %load_ext autoreload
# %autoreload 2

# %%
from get_word_infos import WordInfoFetcher

word = "gutter"
fetcher_audio = WordInfoFetcher(word, source="IPA quiz")

fetcher_audio.show_word_infos()
# Out:
# Word or phrasal verb: gutter
# Cambridge Dictionary URL: https://dictionary.cambridge.org/dictionary/english/gutter
#
# ------------------------------
#
# BRITISH ENGLISH PRONUNCIATION PART:
#  > Phonetic Transcription: /ˈɡʌt.ər/
#  > Pronunciation Youtube videos (Youglish): https://youglish.com/pronounce/gutter/english/uk/
# ------------------------------
# DEFINITIONS:
#   1. the edge of a road where rain flows away
#   2. Gutter talk is offensive language.
#   3. (of a flame or candle) to burn unevenly and weakly, especially before completely stopping burning
#   4. a channel at the lower edge of a roof for carrying away rain, or a side of a road that is lower than the center of the road, where water and garbage collects
#   5. an open pipe, usually at the lower edge of a roof, that collects and carries away rain
#   6. the lowest level, especially of society
#   7. a condition of very low moral standards
# ------------------------------
# EXAMPLES:
# ...

# %% [markdown]
# # Evaluation

# %%
# %run live_speech_to_text.py
# Out:
# Live Speech-to-Text started. Speak into the microphone...
# The script will auto-transcribe when it detects XX second of silence.
# Press Ctrl+C to stop.
#
#
# This is a test.
#
# Stopping...
