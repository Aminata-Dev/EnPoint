# %%
from get_word_infos import WordInfoFetcher

word = "stargazer"
fetcher_audio = WordInfoFetcher(word)

fetcher_audio.show_word_infos()
# Out:
# Word or phrasal verb: stargazer
# Cambridge Dictionary URL: https://dictionary.cambridge.org/dictionary/english/stargazer
#
# ------------------------------
#
# PRONUNCIATION PART:
#  > English Transcription: /ˈstɑːˌɡeɪ.zər/
#  > Youglish UK Pronunciation Youtube videos: https://youglish.com/pronounce/stargazer/english/uk/
# ------------------------------
# DEFINITIONS:
#   1. a person who is involved in astronomy or astrology
#   2. someone who watches famous people in public places
# ------------------------------
# EXAMPLES:
#   1. Environmentalists and stargazers both want dark skies.
#   2. Stargazers with small telescopes may be able to spot the comet on Monday night.
#   3. Celebrities, stargazers, and movie executives all attend the Cannes film festival.
#   4. An army of stargazers followed the singer wherever he went.

# %% [markdown]
# # Evaluation

# %%
# %run live_speech_to_text.py
# Out:
# Live Speech-to-Text started. Speak into the microphone...
# The script will auto-transcribe when it detects XX second of silence.
# Press Ctrl+C to stop.
#
#
# This is a test.
#
# Stopping...
